# %% [markdown]
# For my final project, I will be working with 311 Service Requests from 2010 to Present data set from NYC Open Data. I will analyze service requests based on most and least popular and compare across the five boroughs. I will have a drop down menu, so users can filter by borough and/or by service request type. Below is a mini dive into the data:

# %%
import pandas as pd
url = 'https://data.cityofnewyork.us/resource/erm2-nwe9.json'
calls = pd.read_json(url)
calls.head(10)
# Out:
#    :@computed_region_92fq_4b7q  :@computed_region_efsh_h5xi  \
# 0                         27.0                      17620.0
# 1                         42.0                      10930.0
# 2                         10.0                      11722.0
# 3                         32.0                      11723.0
# 4                         46.0                      24669.0
# 5                         39.0                      13098.0
# 6                          9.0                      10699.0
# 7                          5.0                      14784.0
# 8                         14.0                      10692.0
# 9                         39.0                      13091.0
#
#    :@computed_region_f5dn_yrer  :@computed_region_sbqj_enih  \
# 0                          2.0                         39.0
# 1                         50.0                         27.0
# 2                         12.0                          6.0
# 3                         70.0                          4.0
# ...

# %% [markdown]
# Each data point is a service request call and the parameters of the data set is geography. The column names will need to be cleaned up, but the calls each have x and y coordinates. This will make mapping the data points slightly easier. I will be using statistical analysis to test if compaint types differ by boroughs.
